# %%
# Importações
from pybit.unified_trading import HTTP
import pandas as pd
import numpy as np
from datetime import datetime
import pandas_ta as ta
from enum import Enum

# %%
# Variáveis globais
cliente = HTTP()

data_inicio = '2023-07-01'
# data_fim = '2024-12-31'
data_fim = datetime.now()
saldo = 1000
cripto = 'SOLUSDT'
time_frame = '60'

# %%
# Busca de velas e somar todas as velas entre a data de início e a data de fim
data_inicio_timestamp = int( pd.to_datetime(data_inicio).timestamp() * 1000 )
data_fim_timestamp = int( pd.to_datetime(data_fim).timestamp() * 1000 )

velas_sem_estrutura = []

# loop para somar todas as velas entre a data de início e a data de fim
while data_inicio_timestamp < data_fim_timestamp:
    resposta = cliente.get_kline(symbol=cripto, interval=time_frame, limit=1000, start=data_inicio_timestamp)
    velas_sem_estrutura = velas_sem_estrutura + resposta['result']['list'][ : :-1]
    data_inicio_timestamp = int( velas_sem_estrutura[-1][0] ) + 1000

# %%
# Criação do DataFrame
colunas = ['tempo_abertura', 'abertura', 'maxima', 'minima', 'fechamento', 'volume', 'turnover']
df = pd.DataFrame(velas_sem_estrutura, columns=colunas)

# %%
# TIMESTAMP -> DATETIME
df['tempo_abertura'] = pd.to_datetime(df['tempo_abertura'].astype(np.int64), unit='ms')

# Tratamento dos dados para converter de texto para número com vírgula
df['abertura'] = df['abertura'].astype(float)
df['maxima'] = df['maxima'].astype(float)
df['minima'] = df['minima'].astype(float)
df['fechamento'] = df['fechamento'].astype(float)
df['volume'] = df['volume'].astype(float)
df['turnover'] = df['turnover'].astype(float)

df['ma_50'] = df['fechamento'].rolling(window=50).mean()
df['ma_200'] = df['fechamento'].rolling(window=200).mean()

# %%
def calcula_percentual_lucro_na_compra(preco_compra, preco_venda):
    percentual_lucro = ((preco_venda - preco_compra) / preco_compra) * 100
    # print('Percentual de lucro:', percentual_lucro, '%')
    return percentual_lucro

def calcula_percentual_perda_na_compra(preco_compra, preco_venda):
    percentual_perda = ((preco_compra - preco_venda) / preco_compra) * 100
    # print('Percentual de perda:', percentual_perda, '%')
    return percentual_perda

# %%
class EstadoDeTrade(Enum):
    DE_FORA = 0
    COMPRADO = 1
    VENDIDO = 2

estado_de_trade = EstadoDeTrade.DE_FORA

# %%
for i in range(199, len(df)):
    if estado_de_trade == EstadoDeTrade.DE_FORA:       
        # Avaliar condições de entrada seja na compra ou na venda
        media_rapida = df['ma_50'].iloc[i]
        media_lenta = df['ma_200'].iloc[i]

        if media_rapida > media_lenta: # Caso dê entrada:
            print('Condições de compra atendidas!')
            estado_de_trade = EstadoDeTrade.COMPRADO
            print('Comprou na vela de posição:', i)
            print('Comprou no tempo de abertura:', df['tempo_abertura'].iloc[i])
            preco_compra = df['abertura'].iloc[i]
            print('Preço de compra:', preco_compra)
            print('----------')

    if estado_de_trade == EstadoDeTrade.COMPRADO:
        # Avaliar condições de saída, seja no stop loss ou no alvo
        media_rapida = df['ma_50'].iloc[i]
        media_lenta = df['ma_200'].iloc[i]

        if media_rapida < media_lenta:
            print('Condições de saída da compra atendidas!')
            preco_venda = df['abertura'].iloc[i] 

            if preco_venda < preco_compra: # condição para avaliar perdas
                estado_de_trade = EstadoDeTrade.DE_FORA
                percentual_perda = calcula_percentual_perda_na_compra(preco_compra, preco_venda)
                saldo = saldo - (saldo * percentual_perda / 100)
                print('Stop loss na vela de posição:', i)
                print('Stop loss no tempo de abertura:', df['tempo_abertura'].iloc[i])
                print('Saldo atual:', saldo)
                print('----------')

            if preco_venda > preco_compra:
                # Caso de saída em alvo:
                estado_de_trade = EstadoDeTrade.DE_FORA
                percentual_lucro = calcula_percentual_lucro_na_compra(preco_compra, preco_venda)
                saldo = saldo + (saldo * percentual_lucro / 100)
                print('Saiu no alvo na vela de posição:', i)
                print('Saiu no alvo no tempo de abertura:', df['tempo_abertura'].iloc[i])
                print('Saldo atual:', saldo)
                print('----------')

print('Terminou o backtest!')
print('Saldo final:', saldo)
# Out:
# Condições de compra atendidas!
# Comprou na vela de posição: 199
# Comprou no tempo de abertura: 2023-07-09 07:00:00
# Preço de compra: 21.758
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 474
# Saiu no alvo no tempo de abertura: 2023-07-20 18:00:00
# Saldo atual: 1175.3837668903393
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 654
# Comprou no tempo de abertura: 2023-07-28 06:00:00
# Preço de compra: 24.669
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 748
# Stop loss no tempo de abertura: 2023-08-01 04:00:00
# Saldo atual: 1114.444294765294
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 929
# Comprou no tempo de abertura: 2023-08-08 17:00:00
# Preço de compra: 24.028
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 1116
# Stop loss no tempo de abertura: 2023-08-16 12:00:00
# Saldo atual: 1089.9550910181626
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 1443
# Comprou no tempo de abertura: 2023-08-30 03:00:00
# Preço de compra: 21.575
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 1491
# Stop loss no tempo de abertura: 2023-09-01 03:00:00
# Saldo atual: 1001.3441417877639
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 1674
# Comprou no tempo de abertura: 2023-09-08 18:00:00
# Preço de compra: 19.491
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 1705
# Stop loss no tempo de abertura: 2023-09-10 01:00:00
# Saldo atual: 994.5113076151831
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 1836
# Comprou no tempo de abertura: 2023-09-15 12:00:00
# Preço de compra: 18.999
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 2036
# Saiu no alvo no tempo de abertura: 2023-09-23 20:00:00
# Saldo atual: 1018.6425625660016
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 2170
# Comprou no tempo de abertura: 2023-09-29 10:00:00
# Preço de compra: 20.16
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 2410
# Saiu no alvo no tempo de abertura: 2023-10-09 10:00:00
# Saldo atual: 1130.9155672297743
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 2581
# Comprou no tempo de abertura: 2023-10-16 13:00:00
# Preço de compra: 23.379
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 3379
# Saiu no alvo no tempo de abertura: 2023-11-18 19:00:00
# Saldo atual: 2846.8074788074528
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 3409
# Comprou no tempo de abertura: 2023-11-20 01:00:00
# Preço de compra: 60.784
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 3445
# Stop loss no tempo de abertura: 2023-11-21 13:00:00
# Saldo atual: 2641.062130452604
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 3533
# Comprou no tempo de abertura: 2023-11-25 05:00:00
# Preço de compra: 58.667
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 3591
# Stop loss no tempo de abertura: 2023-11-27 15:00:00
# Saldo atual: 2442.263310535466
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 3640
# Comprou no tempo de abertura: 2023-11-29 16:00:00
# Preço de compra: 60.107
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 3974
# Saiu no alvo no tempo de abertura: 2023-12-13 14:00:00
# Saldo atual: 2727.21502326086
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 4012
# Comprou no tempo de abertura: 2023-12-15 04:00:00
# Preço de compra: 74.487
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 4357
# Saiu no alvo no tempo de abertura: 2023-12-29 13:00:00
# Saldo atual: 3929.5226330966725
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 4460
# Comprou no tempo de abertura: 2024-01-02 20:00:00
# Preço de compra: 107.832
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 4496
# Stop loss no tempo de abertura: 2024-01-04 08:00:00
# Saldo atual: 3605.7794114887006
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 4654
# Comprou no tempo de abertura: 2024-01-10 22:00:00
# Preço de compra: 101.669
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 4717
# Stop loss no tempo de abertura: 2024-01-13 13:00:00
# Saldo atual: 3276.336956528796
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 4816
# Comprou no tempo de abertura: 2024-01-17 16:00:00
# Preço de compra: 99.45
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 4865
# Stop loss no tempo de abertura: 2024-01-19 17:00:00
# Saldo atual: 2913.7490777600083
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 5044
# Comprou no tempo de abertura: 2024-01-27 04:00:00
# Preço de compra: 92.679
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 5250
# Saiu no alvo no tempo de abertura: 2024-02-04 18:00:00
# Saldo atual: 3049.6290884860496
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 5340
# Comprou no tempo de abertura: 2024-02-08 12:00:00
# Preço de compra: 101.232
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 5562
# Saiu no alvo no tempo de abertura: 2024-02-17 18:00:00
# Saldo atual: 3245.894434537561
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 5616
# Comprou no tempo de abertura: 2024-02-20 00:00:00
# Preço de compra: 111.657
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 5629
# Stop loss no tempo de abertura: 2024-02-20 13:00:00
# Saldo atual: 3175.050289190937
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 5793
# Comprou no tempo de abertura: 2024-02-27 09:00:00
# Preço de compra: 111.211
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 6336
# Saiu no alvo no tempo de abertura: 2024-03-21 00:00:00
# Saldo atual: 5472.223198065789
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 6458
# Comprou no tempo de abertura: 2024-03-26 02:00:00
# Preço de compra: 190.211
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 6645
# Stop loss no tempo de abertura: 2024-04-02 21:00:00
# Saldo atual: 5314.855533243986
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 7072
# Comprou no tempo de abertura: 2024-04-20 16:00:00
# Preço de compra: 147.08
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 7210
# Stop loss no tempo de abertura: 2024-04-26 10:00:00
# Saldo atual: 5207.532165459552
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 7388
# Comprou no tempo de abertura: 2024-05-03 20:00:00
# Preço de compra: 142.66
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 7585
# Saiu no alvo no tempo de abertura: 2024-05-12 01:00:00
# Saldo atual: 5313.026122827968
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 7678
# Comprou no tempo de abertura: 2024-05-15 22:00:00
# Preço de compra: 155.6
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 7890
# Saiu no alvo no tempo de abertura: 2024-05-24 18:00:00
# Saldo atual: 5758.965204859673
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 8167
# Comprou no tempo de abertura: 2024-06-05 07:00:00
# Preço de compra: 174.04
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 8244
# Stop loss no tempo de abertura: 2024-06-08 12:00:00
# Saldo atual: 5310.928035968614
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 8675
# Comprou no tempo de abertura: 2024-06-26 11:00:00
# Preço de compra: 136.65
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 8871
# Stop loss no tempo de abertura: 2024-07-04 15:00:00
# Saldo atual: 5216.485627425593
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 9004
# Comprou no tempo de abertura: 2024-07-10 04:00:00
# Preço de compra: 141.64
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 9082
# Stop loss no tempo de abertura: 2024-07-13 10:00:00
# Saldo atual: 5178.551567864393
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 9102
# Comprou no tempo de abertura: 2024-07-14 06:00:00
# Preço de compra: 145.46
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 9528
# Saiu no alvo no tempo de abertura: 2024-08-01 00:00:00
# Saldo atual: 6108.455094281401
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 9713
# Comprou no tempo de abertura: 2024-08-08 17:00:00
# Preço de compra: 158.88
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 9822
# Stop loss no tempo de abertura: 2024-08-13 06:00:00
# Saldo atual: 5599.801639489465
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 9987
# Comprou no tempo de abertura: 2024-08-20 03:00:00
# Preço de compra: 145.33
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 10041
# Stop loss no tempo de abertura: 2024-08-22 09:00:00
# Saldo atual: 5513.105474287157
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 10059
# Comprou no tempo de abertura: 2024-08-23 03:00:00
# Preço de compra: 144.72
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 10199
# Stop loss no tempo de abertura: 2024-08-28 23:00:00
# Saldo atual: 5464.724849961945
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 10492
# Comprou no tempo de abertura: 2024-09-10 04:00:00
# Preço de compra: 132.87
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 10652
# Stop loss no tempo de abertura: 2024-09-16 20:00:00
# Saldo atual: 5390.28252303765
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 10723
# Comprou no tempo de abertura: 2024-09-19 19:00:00
# Preço de compra: 143.68
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 11018
# Saiu no alvo no tempo de abertura: 2024-10-02 02:00:00
# Saldo atual: 5481.070967537587
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 11164
# Comprou no tempo de abertura: 2024-10-08 04:00:00
# Preço de compra: 144.63
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 11205
# Stop loss no tempo de abertura: 2024-10-09 21:00:00
# Saldo atual: 5256.719587271927
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 11275
# Comprou no tempo de abertura: 2024-10-12 19:00:00
# Preço de compra: 146.41
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 11739
# Saiu no alvo no tempo de abertura: 2024-11-01 03:00:00
# Saldo atual: 6018.604633661587
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 11873
# Comprou no tempo de abertura: 2024-11-06 17:00:00
# Preço de compra: 186.26
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 12343
# Saiu no alvo no tempo de abertura: 2024-11-26 07:00:00
# Saldo atual: 7704.369713325096
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 12580
# Comprou no tempo de abertura: 2024-12-06 04:00:00
# Preço de compra: 242.29
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 12669
# Stop loss no tempo de abertura: 2024-12-09 21:00:00
# Saldo atual: 6981.5981437849605
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 13057
# Comprou no tempo de abertura: 2024-12-26 01:00:00
# Preço de compra: 196.63
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 13104
# Stop loss no tempo de abertura: 2024-12-28 00:00:00
# Saldo atual: 6538.479876814324
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 13138
# Comprou no tempo de abertura: 2024-12-29 10:00:00
# Preço de compra: 196.81
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 13202
# Stop loss no tempo de abertura: 2025-01-01 02:00:00
# Saldo atual: 6331.504979031929
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 13225
# Comprou no tempo de abertura: 2025-01-02 01:00:00
# Preço de compra: 196.15
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 13385
# Stop loss no tempo de abertura: 2025-01-08 17:00:00
# Saldo atual: 6281.795482892703
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 13559
# Comprou no tempo de abertura: 2025-01-15 23:00:00
# Preço de compra: 204.41
# ----------
# Condições de saída da compra atendidas!
# Saiu no alvo na vela de posição: 13821
# Saiu no alvo no tempo de abertura: 2025-01-26 21:00:00
# Saldo atual: 7787.631687881414
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 14176
# Comprou no tempo de abertura: 2025-02-10 16:00:00
# Preço de compra: 202.94
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 14222
# Stop loss no tempo de abertura: 2025-02-12 14:00:00
# Saldo atual: 7362.830846328013
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 14663
# Comprou no tempo de abertura: 2025-03-02 23:00:00
# Preço de compra: 176.72
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 14724
# Stop loss no tempo de abertura: 2025-03-05 12:00:00
# Saldo atual: 6126.665210233898
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 14749
# Comprou no tempo de abertura: 2025-03-06 13:00:00
# Preço de compra: 148.74
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 14772
# Stop loss no tempo de abertura: 2025-03-07 12:00:00
# Saldo atual: 5909.591621031715
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 14970
# Comprou no tempo de abertura: 2025-03-15 18:00:00
# Preço de compra: 134.69
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 15037
# Stop loss no tempo de abertura: 2025-03-18 13:00:00
# Saldo atual: 5415.553447055791
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 15082
# Comprou no tempo de abertura: 2025-03-20 10:00:00
# Preço de compra: 133.41
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 15122
# Stop loss no tempo de abertura: 2025-03-22 02:00:00
# Saldo atual: 5195.537708482653
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 15158
# Comprou no tempo de abertura: 2025-03-23 14:00:00
# Preço de compra: 133.55
# ----------
# Condições de saída da compra atendidas!
# Stop loss na vela de posição: 15289
# Stop loss no tempo de abertura: 2025-03-29 01:00:00
# Saldo atual: 5045.759946014227
# ----------
# Condições de compra atendidas!
# Comprou na vela de posição: 15609
# Comprou no tempo de abertura: 2025-04-11 09:00:00
# Preço de compra: 117.54
# ----------
# Terminou o backtest!
# Saldo final: 5045.759946014227
